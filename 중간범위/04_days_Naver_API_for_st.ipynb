# %% [markdown]
# ## **네이버 API를 이용한 크롤링**

# %% [markdown]
# **웹 원리**</p>
# ![http-full-structure.png](data:image/png;base64,...)

# %% [markdown]
# **네이버 개발자 센터: https://developers.naver.com/main/**

# %% [markdown]
# **urllib 패키지**
# *   URL 작업을 위한 여러 모듈을 모은 패키지
# *   URL을 열고 읽기 위한 urllib.request 모듈 제공
# *   urllib.request는 데이터를 전송할 때 인코딩을 해서 버이너리 형태로 전송함
# *   urllib.request 모듈에는 urlopen 함수의 형태로 매우 간단한 인터페이스를 제공

# %%
import sys
import urllib.request
client_id = "9EZO5kxIsocOjQ0UyZCk"
client_secret = "I9wWT6niGk"
encText = urllib.parse.quote("파이썬")
url = "https://openapi.naver.com/v1/search/book?query=" + encText + "&start="+"2"+"&display="+"3" # json 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    results = response_body.decode('utf-8')
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Wed, 29 Jun 2022 23:06:37 +0900",
# 	"total":1600,
# 	"start":2,
# 	"display":3,
# 	"items":[
# 		{
# 			"title":"일잘러의 비밀, 엑셀 대신 <b>파이썬<\/b>으로 업무 자동화하기 (엑셀 반복 업무로 지친 직장인, <b>파이썬<\/b>으로 칼퇴하자)",
# 			"link":"http:\/\/book.naver.com\/bookdb\/book_detail.php?bid=22425526",
# 			"image":"https:\/\/bookthumb-phinf.pstatic.net\/cover\/224\/255\/22425526.jpg?type=m1&udate=20220608",
# 			"author":"포스코인재창조원",
# 			"price":"24000",
# 			"discount":"21600",
# 			"publisher":"한빛미디어",
# 			"pubdate":"20220425",
# 			"isbn":"1162245565 9791162245569",
# 			"description":"일잘러로 거듭나려면, 이제 엑셀 대신 <b>파이썬<\/b>이다!&#x0D;직장인들에게 날개를 달아 줄 <b>파이썬<\/b> 업무 자동화!&#x0D;&#x0D;지금까지 엑셀을 잘만 써 왔는데, 왜 다들 <b>파이썬<\/b>을 하라는 걸까요? 엑셀은 사무 업무에 최적화된 프로그램이지만 대용량 데이터를 처리하거나 반복 업무를 자동화하는 데는 한계가 있다.... "
# 		},
# 		{
# 			"title":"혼자 공부하는 <b>파이썬<\/b> (1:1 과외하듯 배우는 프로그래밍 자습서)",
# 			"link":"http:\/\/book.naver.com\/bookdb\/book_detail.php?bid=22479436",
# 			"image":"https:\/\/bookthumb-phinf.pstatic.net\/cover\/224\/794\/22479436.jpg?type=m1&udate=20220615",
# 			"author":"윤인성",
# 			"price":"22000",
# 			"discount":"19800",
# 			"publisher":"한빛미디어",
# 			"pubdate":"20220601",
# 			"isbn":"1162245654 9791162245651",
# 			"description":"『혼자 공부하는 <b>파이썬<\/b>』이 더욱 흥미있고 알찬 내용으로 개정되었습니다. 프로그래밍이 정말 처음인 입문자도 따라갈 수 있는 친절한 설명과 단계별... 1:1 과외하듯 배우는 <b>파이썬<\/b> 프로그래밍 자습서이 책은 독학으로 <b>파이썬<\/b>을 배우는 입문자가 ‘꼭 필요한 내용을 제대로 학습’할 수 있도록 구성했습니다. 뭘... "
# 		},
# 		{
# 			"title":"Do it! 점프 투 <b>파이썬<\/b>",
# 			"link":"http:\/\/book.naver.com\/bookdb\/book_detail.php?bid=15052904",
# 			"image":"https:\/\/bookthumb-phinf.pstatic.net\/cover\/150\/529\/15052904.jpg?type=m1&udate=20220507",
# 			"author":"박응용",
# 			"price":"18800",
# 			"discount":"16920",
# 			"publisher":"이지스퍼블리싱",
# 			"pubdate":"20190620",
# 			"isbn":"1163030910 9791163030911",
# 			"description":"<b>파이썬<\/b> 4년 연속 베스트셀러 1위!\n《DO IT! 점프 투 <b>파이썬<\/b>》 전면 개정판 출시!문과생도 중고등학생도 직장인도 프로그래밍에 눈뜨게 만든 바로 그 책이... 점프 투 <b>파이썬<\/b>》으로 출간되었던 이 책은 약 4년 동안의 피드백을 반영하여 초보자가 더 빠르게 입문하고, 더 깊이 있게 공부할 수 있도록 개정되었다.... "
# 		}
# 	]
# }

# %%
results
# Out:
# '{\n\t"lastBuildDate":"Wed, 29 Jun 2022 23:06:37 +0900",\n\t"total":1600,\n\t"start":2,\n\t"display":3,\n\t"items":[\n\t\t{\n\t\t\t"title":"일잘러의 비밀, 엑셀 대신 <b>파이썬<\\/b>으로 업무 자동화하기 (엑셀 반복 업무로 지친 직장인, <b>파이썬<\\/b>으로 칼퇴하자)",\n\t\t\t"link":"http:\\/\\/book.naver.com\\/bookdb\\/book_detail.php?bid=22425526",\n\t\t\t"image":"https:\\/\\/bookthumb-phinf.pstatic.net\\/cover\\/224\\/255\\/22425526.jpg?type=m1&udate=20220608",\n\t\t\t"author":"포스코인재창조원",\n\t\t\t"price":"24000",\n\t\t\t"discount":"21600",\n\t\t\t"publisher":"한빛미디어",\n\t\t\t"pubdate":"20220425",\n\t\t\t"isbn":"1162245565 9791162245569",\n\t\t\t"description":"일잘러로 거듭나려면, 이제 엑셀 대신 <b>파이썬<\\/b>이다!&#x0D;직장인들에게 날개를 달아 줄 <b>파이썬<\\/b> 업무 자동화!&#x0D;&#x0D;지금까지 엑셀을 잘만 써 왔는데, 왜 다들 <b>파이썬<\\/b>을 하라는 걸까요? 엑셀은 사무 업무에 최적화된 프로그램이지만 대용량 데이터를 처리하거나 반복 업무를 자동화하는 데는 한계가 있다.... "\n\t\t},\n\t\t{\n\t\t\t"title":"혼자 공부하는 <b>파이썬<\\/b> (1:1 과외하듯 배우는 프로그래밍 자습서)",\n\t\t\t"link":"http:\\/\\/book.naver.com\\/bookdb\\/book_detail.php?bid=22479436",\n\t\t\t"image":"https:\\/\\/bookthumb-phinf.pstatic.net\\/cover\\/224\\/794\\/22479436.jpg?type=m1&udate=20220615",\n\t\t\t"author":"윤인성",\n\t\t\t"price":"22000",\n\t\t\t"discount":"19800",\n\t\t\t"publisher":"한빛미디어",\n\t\t\t"pubdate":"20220601",\n\t\t\t"isbn":"1162245654 9791162245651",\n\t\t\t"description":"『혼자 공부하는 <b>파이썬<\\/b>』이 더욱 흥미있고 알찬 내용으로 개정되었습니다. 프로그래밍이 정말 처음인 입문자도 따라갈 수 있는 친절한 설명과 단계별... 1:1 과외하듯 배우는 <b>파이썬<\\/b> 프로그래밍 자습서이 책은 독학으로 <b>파이썬<\\/b>을 배우는 입문자가 ‘꼭 필요한 내용을 제대로 학습’할 수 있도록 구성했습니다. 뭘... "\n\t\t},\n\t\t{\n\t\t\t"title":"Do it! 점프 투 <b>파이썬<\\/b>",\n\t\t\t"link":"http:\\/\\/book.naver.com\\/bookdb\\/book_detail.php?bid=15052904",\n\t\t\t"image":"https:\\/\\/bookthumb-phinf.pstatic.net\\/cover\\/150\\/529\\/15052904.jpg?type=m1&udate=20220507",\n\t\t\t"author":"박응용",\n\t\t\t"price":"18800",\n\t\t\t"discount":"16920",\n\t\t\t"publisher":"이지스퍼블리싱",\n\t\t\t"pubdate":"20190620",\n\t\t\t"isbn":"1163030910 9791163030911",\n\t\t\t"description":"<b>파이썬<\\/b> 4년 연속 베스트셀러 1위!\\n《DO IT! 점프 투 <b>파이썬<\\/b>》 전면 개정판 출시!문과생도 중고등학생도 직장인도 프로그래밍에 눈뜨게 만든 바로 그 책이... 점프 투 <b>파이썬<\\/b>》으로 출간되었던 이 책은 약 4년 동안의 피드백을 반영하여 초보자가 더 빠르게 입문하고, 더 깊이 있게 공부할 수 있도록 개정되었다.... "\n\t\t}\n\t]\n}'

# %%
print(results)
# Out:
# {
# 	"lastBuildDate":"Wed, 29 Jun 2022 23:06:37 +0900",
# 	"total":1600,
# 	"start":2,
# 	"display":3,
# 	"items":[
# 		{
# 			"title":"일잘러의 비밀, 엑셀 대신 <b>파이썬<\/b>으로 업무 자동화하기 (엑셀 반복 업무로 지친 직장인, <b>파이썬<\/b>으로 칼퇴하자)",
# 			"link":"http:\/\/book.naver.com\/bookdb\/book_detail.php?bid=22425526",
# 			"image":"https:\/\/bookthumb-phinf.pstatic.net\/cover\/224\/255\/22425526.jpg?type=m1&udate=20220608",
# 			"author":"포스코인재창조원",
# 			"price":"24000",
# 			"discount":"21600",
# 			"publisher":"한빛미디어",
# 			"pubdate":"20220425",
# 			"isbn":"1162245565 9791162245569",
# 			"description":"일잘러로 거듭나려면, 이제 엑셀 대신 <b>파이썬<\/b>이다!&#x0D;직장인들에게 날개를 달아 줄 <b>파이썬<\/b> 업무 자동화!&#x0D;&#x0D;지금까지 엑셀을 잘만 써 왔는데, 왜 다들 <b>파이썬<\/b>을 하라는 걸까요? 엑셀은 사무 업무에 최적화된 프로그램이지만 대용량 데이터를 처리하거나 반복 업무를 자동화하는 데는 한계가 있다.... "
# 		},
# 		{
# 			"title":"혼자 공부하는 <b>파이썬<\/b> (1:1 과외하듯 배우는 프로그래밍 자습서)",
# 			"link":"http:\/\/book.naver.com\/bookdb\/book_detail.php?bid=22479436",
# 			"image":"https:\/\/bookthumb-phinf.pstatic.net\/cover\/224\/794\/22479436.jpg?type=m1&udate=20220615",
# 			"author":"윤인성",
# 			"price":"22000",
# 			"discount":"19800",
# 			"publisher":"한빛미디어",
# 			"pubdate":"20220601",
# 			"isbn":"1162245654 9791162245651",
# 			"description":"『혼자 공부하는 <b>파이썬<\/b>』이 더욱 흥미있고 알찬 내용으로 개정되었습니다. 프로그래밍이 정말 처음인 입문자도 따라갈 수 있는 친절한 설명과 단계별... 1:1 과외하듯 배우는 <b>파이썬<\/b> 프로그래밍 자습서이 책은 독학으로 <b>파이썬<\/b>을 배우는 입문자가 ‘꼭 필요한 내용을 제대로 학습’할 수 있도록 구성했습니다. 뭘... "
# 		},
# 		{
# 			"title":"Do it! 점프 투 <b>파이썬<\/b>",
# 			"link":"http:\/\/book.naver.com\/bookdb\/book_detail.php?bid=15052904",
# 			"image":"https:\/\/bookthumb-phinf.pstatic.net\/cover\/150\/529\/15052904.jpg?type=m1&udate=20220507",
# 			"author":"박응용",
# 			"price":"18800",
# 			"discount":"16920",
# 			"publisher":"이지스퍼블리싱",
# 			"pubdate":"20190620",
# 			"isbn":"1163030910 9791163030911",
# 			"description":"<b>파이썬<\/b> 4년 연속 베스트셀러 1위!\n《DO IT! 점프 투 <b>파이썬<\/b>》 전면 개정판 출시!문과생도 중고등학생도 직장인도 프로그래밍에 눈뜨게 만든 바로 그 책이... 점프 투 <b>파이썬<\/b>》으로 출간되었던 이 책은 약 4년 동안의 피드백을 반영하여 초보자가 더 빠르게 입문하고, 더 깊이 있게 공부할 수 있도록 개정되었다.... "
# 		}
# 	]
# }

# %% [markdown]
# **JavaScript Object Notation (JSON)**은 Javascript 객체 문법으로 **구조화된 데이터를 표현**하기 위한 문자 기반의 표준 포맷으로 **"키-값 쌍"으로 이루어진 데이터**. 웹 어플리케이션에서 데이터를 전송할 때 일반적으로 사용(서버에서 클라이언트로 데이터를 전송하여 표현하려거나 반대의 경우).

# %% [markdown]
# **urllib 패키지**
# *  파이썬에서 json 파일을 읽을 수 있는 패키지

# %%
import json

# %%
result = json.loads(results)
result
# Out:
# {'display': 3,
#  'items': [{'author': '포스코인재창조원',
#    'description': '일잘러로 거듭나려면, 이제 엑셀 대신 <b>파이썬</b>이다!&#x0D;직장인들에게 날개를 달아 줄 <b>파이썬</b> 업무 자동화!&#x0D;&#x0D;지금까지 엑셀을 잘만 써 왔는데, 왜 다들 <b>파이썬</b>을 하라는 걸까요? 엑셀은 사무 업무에 최적화된 프로그램이지만 대용량 데이터를 처리하거나 반복 업무를 자동화하는 데는 한계가 있다.... ',
#    'discount': '21600',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/224/255/22425526.jpg?type=m1&udate=20220608',
#    'isbn': '1162245565 9791162245569',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=22425526',
#    'price': '24000',
#    'pubdate': '20220425',
#    'publisher': '한빛미디어',
#    'title': '일잘러의 비밀, 엑셀 대신 <b>파이썬</b>으로 업무 자동화하기 (엑셀 반복 업무로 지친 직장인, <b>파이썬</b>으로 칼퇴하자)'},
#   {'author': '윤인성',
#    'description': '『혼자 공부하는 <b>파이썬</b>』이 더욱 흥미있고 알찬 내용으로 개정되었습니다. 프로그래밍이 정말 처음인 입문자도 따라갈 수 있는 친절한 설명과 단계별... 1:1 과외하듯 배우는 <b>파이썬</b> 프로그래밍 자습서이 책은 독학으로 <b>파이썬</b>을 배우는 입문자가 ‘꼭 필요한 내용을 제대로 학습’할 수 있도록 구성했습니다. 뭘... ',
#    'discount': '19800',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/224/794/22479436.jpg?type=m1&udate=20220615',
#    'isbn': '1162245654 9791162245651',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=22479436',
#    'price': '22000',
#    'pubdate': '20220601',
#    'publisher': '한빛미디어',
#    'title': '혼자 공부하는 <b>파이썬</b> (1:1 과외하듯 배우는 프로그래밍 자습서)'},
#   {'author': '박응용',
#    'description': '<b>파이썬</b> 4년 연속 베스트셀러 1위!\n《DO IT! 점프 투 <b>파이썬</b>》 전면 개정판 출시!문과생도 중고등학생도 직장인도 프로그래밍에 눈뜨게 만든 바로 그 책이... 점프 투 <b>파이썬</b>》으로 출간되었던 이 책은 약 4년 동안의 피드백을 반영하여 초보자가 더 빠르게 입문하고, 더 깊이 있게 공부할 수 있도록 개정되었다.... ',
#    'discount': '16920',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/150/529/15052904.jpg?type=m1&udate=20220507',
#    'isbn': '1163030910 9791163030911',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=15052904',
#    'price': '18800',
#    'pubdate': '20190620',
#    'publisher': '이지스퍼블리싱',
#    'title': 'Do it! 점프 투 <b>파이썬</b>'}],
#  'lastBuildDate': 'Wed, 29 Jun 2022 23:06:37 +0900',
#  'start': 2,
#  'total': 1600}

# %%
result.items()
# Out:
# dict_items([('lastBuildDate', 'Wed, 29 Jun 2022 23:06:37 +0900'), ('total', 1600), ('start', 2), ('display', 3), ('items', [{'title': '일잘러의 비밀, 엑셀 대신 <b>파이썬</b>으로 업무 자동화하기 (엑셀 반복 업무로 지친 직장인, <b>파이썬</b>으로 칼퇴하자)', 'link': 'http://book.naver.com/bookdb/book_detail.php?bid=22425526', 'image': 'https://bookthumb-phinf.pstatic.net/cover/224/255/22425526.jpg?type=m1&udate=20220608', 'author': '포스코인재창조원', 'price': '24000', 'discount': '21600', 'publisher': '한빛미디어', 'pubdate': '20220425', 'isbn': '1162245565 9791162245569', 'description': '일잘러로 거듭나려면, 이제 엑셀 대신 <b>파이썬</b>이다!&#x0D;직장인들에게 날개를 달아 줄 <b>파이썬</b> 업무 자동화!&#x0D;&#x0D;지금까지 엑셀을 잘만 써 왔는데, 왜 다들 <b>파이썬</b>을 하라는 걸까요? 엑셀은 사무 업무에 최적화된 프로그램이지만 대용량 데이터를 처리하거나 반복 업무를 자동화하는 데는 한계가 있다.... '}, {'title': '혼자 공부하는 <b>파이썬</b> (1:1 과외하듯 배우는 프로그래밍 자습서)', 'link': 'http://book.naver.com/bookdb/book_detail.php?bid=22479436', 'image': 'https://bookthumb-phinf.pstatic.net/cover/224/794/22479436.jpg?type=m1&udate=20220615', 'author': '윤인성', 'price': '22000', 'discount': '19800', 'publisher': '한빛미디어', 'pubdate': '20220601', 'isbn': '1162245654 9791162245651', 'description': '『혼자 공부하는 <b>파이썬</b>』이 더욱 흥미있고 알찬 내용으로 개정되었습니다. 프로그래밍이 정말 처음인 입문자도 따라갈 수 있는 친절한 설명과 단계별... 1:1 과외하듯 배우는 <b>파이썬</b> 프로그래밍 자습서이 책은 독학으로 <b>파이썬</b>을 배우는 입문자가 ‘꼭 필요한 내용을 제대로 학습’할 수 있도록 구성했습니다. 뭘... '}, {'title': 'Do it! 점프 투 <b>파이썬</b>', 'link': 'http://book.naver.com/bookdb/book_detail.php?bid=15052904', 'image': 'https://bookthumb-phinf.pstatic.net/cover/150/529/15052904.jpg?type=m1&udate=20220507', 'author': '박응용', 'price': '18800', 'discount': '16920', 'publisher': '이지스퍼블리싱', 'pubdate': '20190620', 'isbn': '1163030910 9791163030911', 'description': '<b>파이썬</b> 4년 연속 베스트셀러 1위!\n《DO IT! 점프 투 <b>파이썬</b>》 전면 개정판 출시!문과생도 중고등학생도 직장인도 프로그래밍에 눈뜨게 만든 바로 그 책이... 점프 투 <b>파이썬</b>》으로 출간되었던 이 책은 약 4년 동안의 피드백을 반영하여 초보자가 더 빠르게 입문하고, 더 깊이 있게 공부할 수 있도록 개정되었다.... '}])])

# %%
result.keys()
# Out:
# dict_keys(['lastBuildDate', 'total', 'start', 'display', 'items'])

# %%
result['items'][0]
# Out:
# {'author': '포스코인재창조원',
#  'description': '일잘러로 거듭나려면, 이제 엑셀 대신 <b>파이썬</b>이다!&#x0D;직장인들에게 날개를 달아 줄 <b>파이썬</b> 업무 자동화!&#x0D;&#x0D;지금까지 엑셀을 잘만 써 왔는데, 왜 다들 <b>파이썬</b>을 하라는 걸까요? 엑셀은 사무 업무에 최적화된 프로그램이지만 대용량 데이터를 처리하거나 반복 업무를 자동화하는 데는 한계가 있다.... ',
#  'discount': '21600',
#  'image': 'https://bookthumb-phinf.pstatic.net/cover/224/255/22425526.jpg?type=m1&udate=20220608',
#  'isbn': '1162245565 9791162245569',
#  'link': 'http://book.naver.com/bookdb/book_detail.php?bid=22425526',
#  'price': '24000',
#  'pubdate': '20220425',
#  'publisher': '한빛미디어',
#  'title': '일잘러의 비밀, 엑셀 대신 <b>파이썬</b>으로 업무 자동화하기 (엑셀 반복 업무로 지친 직장인, <b>파이썬</b>으로 칼퇴하자)'}

# %%
result['items'][0]['title']
# Out:
# '일잘러의 비밀, 엑셀 대신 <b>파이썬</b>으로 업무 자동화하기 (엑셀 반복 업무로 지친 직장인, <b>파이썬</b>으로 칼퇴하자)'

# %%
author = result['items'][0]['author']
author
# Out:
# '포스코인재창조원'

# %%
result['items'][0]['title']
# Out:
# '일잘러의 비밀, 엑셀 대신 <b>파이썬</b>으로 업무 자동화하기 (엑셀 반복 업무로 지친 직장인, <b>파이썬</b>으로 칼퇴하자)'

# %%
titles = [result['items'][n]['title'] for n in range(3)]
titles
# Out:
# ['일잘러의 비밀, 엑셀 대신 <b>파이썬</b>으로 업무 자동화하기 (엑셀 반복 업무로 지친 직장인, <b>파이썬</b>으로 칼퇴하자)',
#  '혼자 공부하는 <b>파이썬</b> (1:1 과외하듯 배우는 프로그래밍 자습서)',
#  'Do it! 점프 투 <b>파이썬</b>']

# %%
authors = [result['items'][n]['author'] for n in range(3)]
authors
# Out:
# ['포스코인재창조원', '윤인성', '박응용']

# %%
pubdates = [result['items'][n]['pubdate'] for n in range(3)]
pubdates
# Out:
# ['20220425', '20220601', '20190620']

# %%
import pandas as pd

# %%
df = pd.DataFrame({"책 제목": titles, '저자': authors, '출간일':pubdates})
df
# Out:
#                                                 책 제목        저자       출간일
# 0  일잘러의 비밀, 엑셀 대신 <b>파이썬</b>으로 업무 자동화하기 (엑셀 반복 업무...  포스코인재창조원  20220425
# 1        혼자 공부하는 <b>파이썬</b> (1:1 과외하듯 배우는 프로그래밍 자습서)       윤인성  20220601
# 2                             Do it! 점프 투 <b>파이썬</b>       박응용  20190620

# %% [markdown]
#  **책제목, 작가, 출판일로 구성된 테이블로 구성된 데이터를 구축**

# %% [markdown]
# *   create_url(): url 값
# *   get_dataframe(): DataFrame 결과

# %%
#사용자 정의 함수
#encText = urllib.parse.quote("파이썬")
#url = "https://openapi.naver.com/v1/search/book.json?query=" + encText + "&start=2&display=3" # json 결과


def create_url(search_type, search_text, start_num, display_num):
    base = "https://openapi.naver.com/v1/search/book.json?query="

    node = search_text + ".json"
    param_query = "?query=" + urllib.parse.quote(search_text)
    param_start = "&start" + str(start_num)
    param_disp =  "&display=" + str(display_num)
 
    return base + node + param_query + param_start + param_disp

# %% [markdown]
# **1) 사용자 정의 함수 : create_url()**
# 1.   parameter 값 정의: search_type, search_text, start_num, display_num
# 2.   return 값 정의 : "https://openapi.naver.com/v1/search/" + "book"+".json?query=" + encText + "&start="+"1"+"&display="+"3"
# 3.   함수명 정의: def create_url(search_type, search_text, start_num, display_num)

# %%
#호출
create_url("book", "파이썬", 1, 50)
# Out:
# 'https://openapi.naver.com/v1/search/book.json?query=파이썬.json?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC&start1&display=50'

# %%
import json

# %%
url = create_url("book", "파이썬", 1, 100)
req = urllib.request.Request(url)
req.add_header("X-Naver-Client-Id",client_id)
req.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)

response_body = response.read()
results = response_body.decode('utf-8')

jResult = json.loads(results)

# %%
jResult
# Out:
# {'display': 3,
#  'items': [{'author': '포스코인재창조원',
#    'description': '일잘러로 거듭나려면, 이제 엑셀 대신 <b>파이썬</b>이다!&#x0D;직장인들에게 날개를 달아 줄 <b>파이썬</b> 업무 자동화!&#x0D;&#x0D;지금까지 엑셀을 잘만 써 왔는데, 왜 다들 <b>파이썬</b>을 하라는 걸까요? 엑셀은 사무 업무에 최적화된 프로그램이지만 대용량 데이터를 처리하거나 반복 업무를 자동화하는 데는 한계가 있다.... ',
#    'discount': '21600',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/224/255/22425526.jpg?type=m1&udate=20220608',
#    'isbn': '1162245565 9791162245569',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=22425526',
#    'price': '24000',
#    'pubdate': '20220425',
#    'publisher': '한빛미디어',
#    'title': '일잘러의 비밀, 엑셀 대신 <b>파이썬</b>으로 업무 자동화하기 (엑셀 반복 업무로 지친 직장인, <b>파이썬</b>으로 칼퇴하자)'},
#   {'author': '윤인성',
#    'description': '『혼자 공부하는 <b>파이썬</b>』이 더욱 흥미있고 알찬 내용으로 개정되었습니다. 프로그래밍이 정말 처음인 입문자도 따라갈 수 있는 친절한 설명과 단계별... 1:1 과외하듯 배우는 <b>파이썬</b> 프로그래밍 자습서이 책은 독학으로 <b>파이썬</b>을 배우는 입문자가 ‘꼭 필요한 내용을 제대로 학습’할 수 있도록 구성했습니다. 뭘... ',
#    'discount': '19800',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/224/794/22479436.jpg?type=m1&udate=20220615',
#    'isbn': '1162245654 9791162245651',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=22479436',
#    'price': '22000',
#    'pubdate': '20220601',
#    'publisher': '한빛미디어',
#    'title': '혼자 공부하는 <b>파이썬</b> (1:1 과외하듯 배우는 프로그래밍 자습서)'},
#   {'author': '박응용',
#    'description': '<b>파이썬</b> 4년 연속 베스트셀러 1위!\n《DO IT! 점프 투 <b>파이썬</b>》 전면 개정판 출시!문과생도 중고등학생도 직장인도 프로그래밍에 눈뜨게 만든 바로 그 책이... 점프 투 <b>파이썬</b>》으로 출간되었던 이 책은 약 4년 동안의 피드백을 반영하여 초보자가 더 빠르게 입문하고, 더 깊이 있게 공부할 수 있도록 개정되었다.... ',
#    'discount': '16920',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/150/529/15052904.jpg?type=m1&udate=20220507',
#    'isbn': '1163030910 9791163030911',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=15052904',
#    'price': '18800',
#    'pubdate': '20190620',
#    'publisher': '이지스퍼블리싱',
#    'title': 'Do it! 점프 투 <b>파이썬</b>'}],
#  'lastBuildDate': 'Wed, 29 Jun 2022 23:06:38 +0900',
#  'start': 2,
#  'total': 1600}

# %% [markdown]
# **첫번째 책의 제목을 출력**

# %% [markdown]
# **전체 책의 갯수를 출력**

# %% [markdown]
# **전체 책제목, 작가, 출판일을 각각 출력**
# * list-for

# %%
# titles = 
# titles

# %%
# authors = 
# authors

# %%
# pubdates = 
# pubdates

# %% [markdown]
# **데이터 프레임 만들기**

# %%
pd.DataFrame()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# **2) 사용자 정의 함수 : get_dataframe()**
# 1.   parameter 값 정의: url
# 2.   return 값 정의 : DataFrame
# 3.   함수명 정의: def get_dataframe(url)

# %%
def get_dataframe(url):
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id", client_id)
    request.add_header("X-Naver-Client-Secret", client_secret)
    
    response = urllib.request.urlopen(request)

    result = json.loads(response.read().decode('utf-8'))
    
    end_num = result['display']
    
    titles = [result['items'][n]['title'] for n in range(end_num)]
    authors = [result['items'][n]['author'] for n in range(end_num)]
    pubdates = [result['items'][n]['pubdate'] for n in range(end_num)]
    
    return pd.DataFrame({'책제목':titles, '저자':authors, '출판일':pubdates })

# %% [markdown]
# * **pd.concat**

# %%
#url = 
get_dataframe(create_url("book", "파이썬", 1, 100))
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# <ipython-input-27-6991dc1dd350> in <module>()
#       1 #url =
# ----> 2 get_dataframe(create_url("book", "파이썬", 1, 100))
#
# <ipython-input-26-9a0a7a6676e1> in get_dataframe(url)
#       4     request.add_header("X-Naver-Client-Secret", client_secret)
#       5
# ----> 6     response = urllib.request.urlopen(request)
#       7
#       8     result = json.loads(response.read().decode('utf-8'))
#
# /usr/lib/python3.7/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# /usr/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     523             req = meth(req)
#     524
# --> 525         response = self._open(req, data)
#     526
#     527         # post-process response
#
# /usr/lib/python3.7/urllib/request.py in _open(self, req, data)
#     541         protocol = req.type
#     542         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 543                                   '_open', req)
#     544         if result:
#     545             return result
#
# /usr/lib/python3.7/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# /usr/lib/python3.7/urllib/request.py in https_open(self, req)
#    1391         def https_open(self, req):
#    1392             return self.do_open(http.client.HTTPSConnection, req,
# -> 1393                 context=self._context, check_hostname=self._check_hostname)
#    1394
#    1395         https_request = AbstractHTTPHandler.do_request_
#
# /usr/lib/python3.7/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1348             try:
#    1349                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1350                           encode_chunked=req.has_header('Transfer-encoding'))
#    1351             except OSError as err: # timeout error
#    1352                 raise URLError(err)
#
# /usr/lib/python3.7/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1279                 encode_chunked=False):
#    1280         """Send a complete request to the server."""
# -> 1281         self._send_request(method, url, body, headers, encode_chunked)
#    1282
#    1283     def _send_request(self, method, url, body, headers, encode_chunked):
#
# /usr/lib/python3.7/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1290             skips['skip_accept_encoding'] = 1
#    1291
# -> 1292         self.putrequest(method, url, **skips)
#    1293
#    1294         # chunked encoding will happen if HTTP/1.1 is used and either
#
# /usr/lib/python3.7/http/client.py in putrequest(self, method, url, skip_host, skip_accept_encoding)
#    1128         request = '%s %s %s' % (method, url, self._http_vsn_str)
#    1129
# -> 1130         self._output(self._encode_request(request))
#    1131
#    1132         if self._http_vsn == 11:
#
# /usr/lib/python3.7/http/client.py in _encode_request(self, request)
#    1208     def _encode_request(self, request):
#    1209         # ASCII also helps prevent CVE-2019-9740.
# -> 1210         return request.encode('ascii')
#    1211
#    1212     def _validate_method(self, method):
#
# UnicodeEncodeError: 'ascii' codec can't encode characters in position 31-33: ordinal not in range(128)

# %%
df1 = get_dataframe(create_url("book", "파이썬", 1, 100))
df1

# %%
df2 = get_dataframe(create_url("book", "파이썬", 101, 100))
df2

# %%
df3 = get_dataframe(create_url("book", "파이썬", 201, 100))
df3

# %%
pd.concat([df1, df2, df3])

# %% [markdown]
# 질문)
# **어떻게 한번에 100개 이상의 데이터를 다운로드 받을 것인가?**

# %%
#start_num
[n for n in range(1,300,100)]

# %%
result_search = []

for n in range(1, 300,100):
    url = create_url("book", "파이썬", n, 100)
    result_search.append(get_dataframe(url))

result_search

result_search = pd.concat(result_search) # pd.concat([df, df, df])
result_search

# %%
result_search.info()

# %%
#엑셀파일로 저장하기
result_search.to_excel('book.xlsx', sheet_name='Sheet1')

# %% [markdown]
# **참고)**

# %%
# 판다스 데이블 전체보기
#pd.set_option('display.max_rows', None)
# 판다스 초기화
pd.reset_option('^display.', silent=True)
